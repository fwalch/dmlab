# %%
emotions = pd.read_json('data/emotions.json')
landmarks = pd.read_json('data/landmarks.json')
facs = pd.read_json('data/facs.json')

# %%
emotions[['emotion']].describe()
# Out:
#           emotion
# count  327.000000
# mean     4.440367
# std      2.072747
# min      1.000000
# 25%      3.000000
# 50%      5.000000
# 75%      7.000000
# max      7.000000
#
# [8 rows x 1 columns]

# %%
landmarks[['x', 'y']].describe()
# Out:
#                   x             y
# count  40324.000000  40324.000000
# mean     312.887142    263.251797
# std       63.571034     70.341322
# min      111.983900     78.424542
# 25%      269.729630    203.717547
# 50%      311.990340    267.735395
# 75%      355.707040    316.955578
# max      527.095710    474.288950
#
# [8 rows x 2 columns]

# %%
facs[['au', 'intensity']].describe()
# Out:
#                 au    intensity
# count  2214.000000  2214.000000
# mean     14.456640     0.804426
# std      10.537119     1.444299
# min       1.000000     0.000000
# 25%       5.000000     0.000000
# 50%      14.000000     0.000000
# 75%      24.000000     1.000000
# max      64.000000     5.000000
#
# [8 rows x 2 columns]

# %%
facs[['au', 'intensity']].groupby(['au']).describe()
# Out:
#            au   intensity
# au
# 1  count  177  177.000000
#    mean     1    0.474576
#    std      0    1.082231
#    min      1    0.000000
#    25%      1    0.000000
#    50%      1    0.000000
#    75%      1    0.000000
#    max      1    4.000000
# 2  count  117  117.000000
#    mean     2    0.478632
#    std      0    1.111060
#    min      2    0.000000
#    25%      2    0.000000
#    50%      2    0.000000
#    75%      2    0.000000
#    max      2    4.000000
# 4  count  194  194.000000
#    mean     4    0.701031
#    std      0    1.363210
#    min      4    0.000000
#    25%      4    0.000000
#    50%      4    0.000000
#    75%      4    0.000000
#    max      4    5.000000
# 5  count  102  102.000000
#    mean     5    1.166667
#    std      0    1.554829
#    min      5    0.000000
#    25%      5    0.000000
#    50%      5    0.000000
#    75%      5    2.000000
#    max      5    5.000000
# 6  count  123  123.000000
#    mean     6    0.203252
#    std      0    0.652352
#    min      6    0.000000
#    25%      6    0.000000
#    50%      6    0.000000
#    75%      6    0.000000
#    max      6    4.000000
# 7  count  121  121.000000
#    mean     7    0.528926
#    std      0    1.211572
#    min      7    0.000000
#    25%      7    0.000000
#    50%      7    0.000000
#    75%      7    0.000000
#    max      7    5.000000
# 9  count   75   75.000000
#    mean     9    2.293333
#    std      0    2.173385
#    min      9    0.000000
#    25%      9    0.000000
#    50%      9    3.000000
#    75%      9    4.000000
#    max      9    5.000000
# 10 count   21   21.000000
#    mean    10    1.380952
#    std      0    1.321975
#    min     10    0.000000
#           ...         ...
#
# [312 rows x 2 columns]
